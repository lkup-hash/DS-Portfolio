# %% [markdown]
# # This Python script will simulate battles for the popular board game "Risk Godstorm"

# %%
import random

def risky(attacking_force, defensive_force, god_of_war, goddess_of_magic_on_attack, goddess_of_magic_on_defense):
	if god_of_war.lower() == "no" and goddess_of_magic_on_attack.lower() == "no" and goddess_of_magic_on_defense.lower() == "no":

		while attacking_force > 3 and defensive_force > 2:
			
			firsta = random.randint(1,6)
			seconda = random.randint(1,6)
			thirda = random.randint(1,6)
			firstd = random.randint(1,6)
			secondd = random.randint(1,6)

			attackinglist = [firsta,seconda,thirda]
			sortedattckinglist = sorted(attackinglist)

			topa = max(firsta,seconda,thirda)
			bottoma = sortedattckinglist[1]


			topd = max(firstd, secondd)
			bottomd = min(firstd, secondd)


			if topa > topd:
				defensive_force -= 1
			else:
				attacking_force -= 1


			if bottoma > bottomd:
				defensive_force -= 1
			else:
				attacking_force -= 1

		return(attacking_force, defensive_force)



	elif god_of_war.lower() == "yes" and goddess_of_magic_on_attack.lower() == "no" and goddess_of_magic_on_defense.lower() == "no":

		while attacking_force > 3 and defensive_force > 2:
			
			firsta = random.randint(1,6)
			seconda = random.randint(1,6)
			thirda = random.randint(1,6)
			firstd = random.randint(1,6)
			secondd = random.randint(1,6)

			attackinglist = [firsta,seconda,thirda]
			sortedattckinglist = sorted(attackinglist)

			topa = max(firsta,seconda,thirda)
			bottoma = sortedattckinglist[1]


			topd = max(firstd, secondd)
			bottomd = min(firstd, secondd)


			if topa >= topd:
				defensive_force -= 1
			else:
				attacking_force -= 1


			if bottoma >= bottomd:
				defensive_force -= 1
			else:
				attacking_force -= 1

		return(attacking_force, defensive_force)


	elif god_of_war.lower() == "yes" and goddess_of_magic_on_attack.lower() == "yes" and goddess_of_magic_on_defense.lower() == "no":

		while attacking_force > 3 and defensive_force > 2:
			firsta = random.randint(2,6)
			seconda = random.randint(2,6)
			thirda = random.randint(2,6)
			firstd = random.randint(1,6)
			secondd = random.randint(1,6)

			attackinglist = [firsta,seconda,thirda]
			sortedattckinglist = sorted(attackinglist)

			topa = max(firsta,seconda,thirda)
			bottoma = sortedattckinglist[1]


			topd = max(firstd, secondd)
			bottomd = min(firstd, secondd)


			if topa >= topd:
				defensive_force -= 1
			else:
				attacking_force -= 1


			if bottoma >= bottomd:
				defensive_force -= 1
			else:
				attacking_force -= 1

		return(attacking_force, defensive_force)


	elif god_of_war.lower() == "no" and goddess_of_magic_on_attack.lower() == "yes" and goddess_of_magic_on_defense.lower() == "no":

		while attacking_force > 3 and defensive_force > 2:
			firsta = random.randint(2,6)
			seconda = random.randint(2,6)
			thirda = random.randint(2,6)
			firstd = random.randint(1,6)
			secondd = random.randint(1,6)

			attackinglist = [firsta,seconda,thirda]
			sortedattckinglist = sorted(attackinglist)

			topa = max(firsta,seconda,thirda)
			bottoma = sortedattckinglist[1]


			topd = max(firstd, secondd)
			bottomd = min(firstd, secondd)


			if topa > topd:
				defensive_force -= 1
			else:
				attacking_force -= 1


			if bottoma > bottomd:
				defensive_force -= 1
			else:
				attacking_force -= 1

		return(attacking_force, defensive_force)



	elif god_of_war.lower() == "no" and goddess_of_magic_on_attack.lower() == "no" and goddess_of_magic_on_defense.lower() == "yes":

		while attacking_force > 3 and defensive_force > 2:
			firsta = random.randint(1,6)
			seconda = random.randint(1,6)
			thirda = random.randint(1,6)
			firstd = random.randint(2,6)
			secondd = random.randint(2,6)

			attackinglist = [firsta,seconda,thirda]
			sortedattckinglist = sorted(attackinglist)

			topa = max(firsta,seconda,thirda)
			bottoma = sortedattckinglist[1]


			topd = max(firstd, secondd)
			bottomd = min(firstd, secondd)


			if topa > topd:
				defensive_force -= 1
			else:
				attacking_force -= 1


			if bottoma > bottomd:
				defensive_force -= 1
			else:
				attacking_force -= 1
		return(attacking_force, defensive_force)
		#return("The simulation has ended, the attacking force now numbers: " + str(attacking_force)+ " and the defensive force now numbers: " +str(defensive_force))

	else: 
		return("Error on God of War input or Goddess of Magic inputs.''Yes'' or ''No'' must be in quotations for all 3 options. Futhermore, you must complete the god war battle beforehand (there cannot be gods on opposing forces)")



#print(risky(1000,437, "yes" , "yes" , "no"))



def riskyer(battles_to_simulate, attacking_force, defensive_force, god_of_war, goddess_of_magic_on_attack, goddess_of_magic_on_defense):
	
	wins=0
	losses=0

	a = attacking_force

	b = defensive_force

	for i in range(0,battles_to_simulate):
		
		attacking_force = a

		defensive_force = b
		result = risky(attacking_force, defensive_force, god_of_war, goddess_of_magic_on_attack, goddess_of_magic_on_defense)

		defensive_force = result[1]
		attacking_force = result[0]		
		if attacking_force < defensive_force:
			losses += 1
		else:
			wins+=1

	realwins = float(wins)
	reallosses = float(losses)

	winpct = (realwins/(realwins+reallosses))*100

	return(winpct, wins, losses)


#print(riskyer(100, 1000,437, "no" , "no" , "no"))

# %% [markdown]
# # In order to simulate a single battle, edit the fields below and run the code

# %% [markdown]
# ### As in line with game rules, battles cannot carry on in the same manner once the attacking force is under 3 or the defensive force is under 2. The output will provide the new numbers of attacking and defending forces.

# %%
attacking_force = 550
defensive_force = 437
god_of_war = "no"
goddess_of_magic_on_attack = "no"
goddess_of_magic_on_defense = "yes"

# %%
final = risky(attacking_force, defensive_force, god_of_war, goddess_of_magic_on_attack, goddess_of_magic_on_defense)
print("The simulation has ended, the attacking force now numbers: " + str(final[0])+ " and the defensive force now numbers: " +str(final[1]))
# Out:
# The simulation has ended, the attacking force now numbers: 2 and the defensive force now numbers: 23

# %% [markdown]
# # In order to simulate multiple battles, edit the fields below and run the code

# %% [markdown]
# ### The output will include win percentage of the attacking force, the number of times the attackers won, and the number of times the defenders won.

# %%
battles_to_simulate = 100
attacking_force = 550
defensive_force = 437
god_of_war = "no"
goddess_of_magic_on_attack = "no"
goddess_of_magic_on_defense = "yes"

# %%
final = riskyer(battles_to_simulate,attacking_force, defensive_force, god_of_war, goddess_of_magic_on_attack, goddess_of_magic_on_defense)
print("The attacking force won "+str(round(final[0],2))+"% of the simulated battles winning "+str(final[1])+" battles and losing "+str(final[2])+" battles.")
# Out:
# The attacking force won 36.0% of the simulated battles winning 36 battles and losing 64 battles.
